# %% [markdown]
# <a href="https://colab.research.google.com/github/srq0617/hanul/blob/master/%ED%95%99%EC%88%A0%EC%A0%9C%20SRCNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/srq0617/hanul.git
# Out:
# Cloning into 'hanul'...
# remote: Enumerating objects: 6006, done.
# remote: Counting objects: 100% (6006/6006), done.
# remote: Compressing objects: 100% (6004/6004), done.
# remote: Total 6006 (delta 0), reused 6006 (delta 0), pack-reused 0
# Receiving objects: 100% (6006/6006), 981.35 MiB | 15.84 MiB/s, done.
# Checking out files: 100% (6000/6000), done.

# %%
import os
import tensorflow as tf
config = tf.ConfigProto()
config.gpu_options.allow_growth=True
session = tf.Session(config=config)
from keras import optimizers
import glob
import numpy as np
np.set_printoptions(threshold=np.inf)
import matplotlib.pyplot as plt
from keras.preprocessing.image import load_img, array_to_img, img_to_array, ImageDataGenerator
from keras.models import Sequential, Model
from keras.layers import Dense, Conv2D, MaxPooling2D, UpSampling2D, Flatten, Input, BatchNormalization
np.random.seed(111)
# Out:
# Using TensorFlow backend.

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-ed28b976-cdb9-4500-b92a-975a9f4649b9" name="files[]" multiple disabled />
#      <output id="result-ed28b976-cdb9-4500-b92a-975a9f4649b9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving sample (1).png to sample (1).png
# User uploaded file "sample (1).png" with length 291805 bytes

# %%
low_train_path = r'./hanul/Low images'
clean_train_path=r'./hanul/Clean images'
train_path = os.path.join(low_train_path,'Low images')
train_clean_path = os.path.join(clean_train_path,'Clean images')



train = sorted(glob.glob(os.path.join(train_path,'*.png')))
train_cleaned = sorted(glob.glob(os.path.join(train_clean_path,'*.png')))



test_path=r'./hanul/Low images'
test_input_path = os.path.join(test_path,'Low images')

test = sorted(glob.glob(os.path.join(test_input_path,'sample (1).png')))



print("Total number of images in the training set: ", len(train)) # Training set -장
print("Total number of cleaned images found: ", len(train_cleaned))       # Train cleaned set -장
print("Total number of samples in the test set: ", len(test))     # Test set -장

epochs = 100
batch_size = 32
# Out:
# Total number of images in the training set:  3000
# Total number of cleaned images found:  3000
# Total number of samples in the test set:  1

# %%
X = [] # 인풋에 들어가는 image 리스트 : Train data
X_target = [] # 아웃풋에 들어가는 image 리스트 : Train_cleaned data

for img in train:
    img = load_img(img, grayscale=True,target_size=(512,512))
    img = img_to_array(img).astype('float32')/255.
    X.append(img)

for img in train_cleaned:
    img = load_img(img, grayscale=True,target_size=(512,512))
    img = img_to_array(img).astype('float32')/255.
    X_target.append(img)

X = np.array(X) # image 데이터, 리스트를 numpy array로 형변환, 이렇게 하면 shape 함수 등을 쓸 수 있음
X_target = np.array(X_target) # image 데이터, 리스트를 numpy array로 형변환

print("Size of X : ", X.shape) # Size of X : (144,420,540,1) , Training set 144장
print("Size of X_target : ", X_target.shape) # Size of Y : (144,420,540,1) , Train cleaned 144장

#####################################################
# 테스트이미지 불러오기

test_list=[]
for img in test:
    img = load_img(img, grayscale=True,target_size=(512,512))
    img = img_to_array(img).astype('float32')/255.
    test_list.append(img)
# Out:
# /usr/local/lib/python3.6/dist-packages/keras_preprocessing/image/utils.py:104: UserWarning: grayscale is deprecated. Please use color_mode = "grayscale"
#   warnings.warn('grayscale is deprecated. Please use '
# Size of X :  (3000, 512, 512, 1)
# Size of X_target :  (3000, 512, 512, 1)

# %%
def build_RPILSR():
    input_img = Input(shape=(512, 512, 1), name='image_input')

    #### 아키톆쳐
    x = Conv2D(64, (9, 9), activation='relu',kernel_initializer='he_normal', padding='same')(input_img)
    x = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(x)
    x = Conv2D(1, (5, 5), activation='relu',kernel_initializer='he_normal', padding='same')(x)

    # model
    RPILSR = Model(inputs=input_img, outputs=x)

    return RPILSR

# %%
model = build_RPILSR()
model.compile(optimizer=optimizers.Adam(), loss='MSE')

# %%
hist = model.fit(X, X_target, epochs=epochs, batch_size=batch_size)
# Out:
# Epoch 1/100
# 3000/3000 [==============================] - 67s 22ms/step - loss: 0.0016
# Epoch 2/100
# 3000/3000 [==============================] - 66s 22ms/step - loss: 4.8843e-04
# Epoch 3/100
# 3000/3000 [==============================] - 66s 22ms/step - loss: 4.4980e-04
# Epoch 4/100
# 3000/3000 [==============================] - 66s 22ms/step - loss: 4.3264e-04
# Epoch 5/100
# 3000/3000 [==============================] - 66s 22ms/step - loss: 4.1737e-04
# Epoch 6/100
# 3000/3000 [==============================] - 66s 22ms/step - loss: 4.0507e-04
# Epoch 7/100
# 3000/3000 [==============================] - 66s 22ms/step - loss: 3.9993e-04
# Epoch 8/100
# 3000/3000 [==============================] - 66s 22ms/step - loss: 3.9316e-04
# Epoch 9/100
# 3000/3000 [==============================] - 66s 22ms/step - loss: 3.9278e-04
# Epoch 10/100
# 3000/3000 [==============================] - 66s 22ms/step - loss: 3.8478e-04
# Epoch 11/100
# 3000/3000 [==============================] - 66s 22ms/step - loss: 3.7993e-04
# Epoch 12/100
# 3000/3000 [==============================] - 66s 22ms/step - loss: 3.7959e-04
# Epoch 13/100
# 3000/3000 [==============================] - 66s 22ms/step - loss: 3.7455e-04
# Epoch 14/100
# 3000/3000 [==============================] - 66s 22ms/step - loss: 3.7206e-04
# Epoch 15/100
# 3000/3000 [==============================] - 66s 22ms/step - loss: 3.7076e-04
# Epoch 16/100
# 3000/3000 [==============================] - 66s 22ms/step - loss: 3.6924e-04
# Epoch 17/100
# 3000/3000 [==============================] - 66s 22ms/step - loss: 3.6585e-04
# Epoch 18/100
# 3000/3000 [==============================] - 66s 22ms/step - loss: 3.6951e-04
# Epoch 19/100
# 3000/3000 [==============================] - 66s 22ms/step - loss: 3.6156e-04
# Epoch 20/100
# 3000/3000 [==============================] - 66s 22ms/step - loss: 3.6173e-04
# Epoch 21/100
# 3000/3000 [==============================] - 66s 22ms/step - loss: 3.5984e-04
# Epoch 22/100
# 3000/3000 [==============================] - 66s 22ms/step - loss: 3.6088e-04
# Epoch 23/100
# 3000/3000 [==============================] - 66s 22ms/step - loss: 3.5739e-04
# Epoch 24/100
# 3000/3000 [==============================] - 66s 22ms/step - loss: 3.5784e-04
# Epoch 25/100
# 3000/3000 [==============================] - 66s 22ms/step - loss: 3.6045e-04
# Epoch 26/100
# 3000/3000 [==============================] - 66s 22ms/step - loss: 3.5361e-04
# Epoch 27/100
# 3000/3000 [==============================] - 66s 22ms/step - loss: 3.6205e-04
# Epoch 28/100
# 3000/3000 [==============================] - 66s 22ms/step - loss: 3.5200e-04
# Epoch 29/100
# 3000/3000 [==============================] - 66s 22ms/step - loss: 3.5281e-04
# Epoch 30/100
# 3000/3000 [==============================] - 66s 22ms/step - loss: 3.5506e-04
# Epoch 31/100
# 3000/3000 [==============================] - 66s 22ms/step - loss: 3.5795e-04
# Epoch 32/100
# 3000/3000 [==============================] - 66s 22ms/step - loss: 3.4734e-04
# Epoch 33/100
# 3000/3000 [==============================] - 66s 22ms/step - loss: 3.4906e-04
# Epoch 34/100
# 3000/3000 [==============================] - 66s 22ms/step - loss: 3.4888e-04
# Epoch 35/100
# 3000/3000 [==============================] - 66s 22ms/step - loss: 3.4666e-04
# Epoch 36/100
# 3000/3000 [==============================] - 66s 22ms/step - loss: 3.5244e-04
# Epoch 37/100
# 3000/3000 [==============================] - 66s 22ms/step - loss: 3.4387e-04
# Epoch 38/100
# 3000/3000 [==============================] - 66s 22ms/step - loss: 3.5126e-04
# Epoch 39/100
# 3000/3000 [==============================] - 66s 22ms/step - loss: 3.4913e-04
# Epoch 40/100
# 3000/3000 [==============================] - 66s 22ms/step - loss: 3.4242e-04
# Epoch 41/100
# 3000/3000 [==============================] - 66s 22ms/step - loss: 3.6000e-04
# Epoch 42/100
# 3000/3000 [==============================] - 66s 22ms/step - loss: 3.4358e-04
# Epoch 43/100
# 3000/3000 [==============================] - 66s 22ms/step - loss: 3.4039e-04
# Epoch 44/100
# 3000/3000 [==============================] - 66s 22ms/step - loss: 3.3960e-04
# Epoch 45/100
# 3000/3000 [==============================] - 66s 22ms/step - loss: 3.6010e-04
# Epoch 46/100
# 3000/3000 [==============================] - 66s 22ms/step - loss: 3.3930e-04
# Epoch 47/100
# 3000/3000 [==============================] - 66s 22ms/step - loss: 3.3806e-04
# Epoch 48/100
# 3000/3000 [==============================] - 66s 22ms/step - loss: 3.3705e-04
# Epoch 49/100
# 3000/3000 [==============================] - 66s 22ms/step - loss: 3.3815e-04
# Epoch 50/100
# 3000/3000 [==============================] - 66s 22ms/step - loss: 3.5882e-04
# Epoch 51/100
# 3000/3000 [==============================] - 66s 22ms/step - loss: 3.3672e-04
# Epoch 52/100
# 3000/3000 [==============================] - 66s 22ms/step - loss: 3.3553e-04
# Epoch 53/100
# 3000/3000 [==============================] - 66s 22ms/step - loss: 3.3527e-04
# Epoch 54/100
# 3000/3000 [==============================] - 66s 22ms/step - loss: 3.5824e-04
# Epoch 55/100
# 3000/3000 [==============================] - 66s 22ms/step - loss: 3.3521e-04
# Epoch 56/100
# 3000/3000 [==============================] - 66s 22ms/step - loss: 3.3422e-04
# Epoch 57/100
# 3000/3000 [==============================] - 66s 22ms/step - loss: 3.3412e-04
# Epoch 58/100
# 3000/3000 [==============================] - 66s 22ms/step - loss: 3.3426e-04
# Epoch 59/100
# 3000/3000 [==============================] - 66s 22ms/step - loss: 3.4370e-04
# Epoch 60/100
# 3000/3000 [==============================] - 66s 22ms/step - loss: 3.3577e-04
# Epoch 61/100
# 3000/3000 [==============================] - 66s 22ms/step - loss: 3.3213e-04
# Epoch 62/100
# 3000/3000 [==============================] - 66s 22ms/step - loss: 3.4691e-04
# Epoch 63/100
# 3000/3000 [==============================] - 66s 22ms/step - loss: 3.3300e-04
# Epoch 64/100
# 3000/3000 [==============================] - 66s 22ms/step - loss: 3.3103e-04
# Epoch 65/100
# 3000/3000 [==============================] - 66s 22ms/step - loss: 3.3160e-04
# Epoch 66/100
# 3000/3000 [==============================] - 66s 22ms/step - loss: 3.3086e-04
# Epoch 67/100
# 3000/3000 [==============================] - 66s 22ms/step - loss: 3.3956e-04
# Epoch 68/100
# 3000/3000 [==============================] - 66s 22ms/step - loss: 3.3110e-04
# Epoch 69/100
# 3000/3000 [==============================] - 66s 22ms/step - loss: 3.3969e-04
# Epoch 70/100
# 3000/3000 [==============================] - 66s 22ms/step - loss: 3.2930e-04
# Epoch 71/100
# 3000/3000 [==============================] - 66s 22ms/step - loss: 3.3855e-04
# Epoch 72/100
# 3000/3000 [==============================] - 66s 22ms/step - loss: 3.4484e-04
# Epoch 73/100
# 3000/3000 [==============================] - 66s 22ms/step - loss: 3.2828e-04
# Epoch 74/100
# 3000/3000 [==============================] - 66s 22ms/step - loss: 3.2812e-04
# Epoch 75/100
# 3000/3000 [==============================] - 66s 22ms/step - loss: 3.2834e-04
# Epoch 76/100
# 3000/3000 [==============================] - 66s 22ms/step - loss: 3.2845e-04
# Epoch 77/100
# 3000/3000 [==============================] - 66s 22ms/step - loss: 3.2986e-04
# Epoch 78/100
# 3000/3000 [==============================] - 66s 22ms/step - loss: 3.3745e-04
# Epoch 79/100
# 3000/3000 [==============================] - 66s 22ms/step - loss: 3.2785e-04
# Epoch 80/100
# 3000/3000 [==============================] - 66s 22ms/step - loss: 3.2682e-04
# Epoch 81/100
# 3000/3000 [==============================] - 65s 22ms/step - loss: 5.6866e-04
# Epoch 82/100
# 3000/3000 [==============================] - 65s 22ms/step - loss: 3.9107e-04
# Epoch 83/100
# 3000/3000 [==============================] - 65s 22ms/step - loss: 3.7363e-04
# Epoch 84/100
# 3000/3000 [==============================] - 65s 22ms/step - loss: 3.6162e-04
# Epoch 85/100
# 3000/3000 [==============================] - 65s 22ms/step - loss: 3.5587e-04
# Epoch 86/100
# 3000/3000 [==============================] - 65s 22ms/step - loss: 3.5310e-04
# Epoch 87/100
# 3000/3000 [==============================] - 65s 22ms/step - loss: 3.5033e-04
# Epoch 88/100
# 3000/3000 [==============================] - 65s 22ms/step - loss: 3.4841e-04
# Epoch 89/100
# 3000/3000 [==============================] - 65s 22ms/step - loss: 3.4773e-04
# Epoch 90/100
# 3000/3000 [==============================] - 65s 22ms/step - loss: 3.4612e-04
# Epoch 91/100
# 3000/3000 [==============================] - 65s 22ms/step - loss: 3.4632e-04
# Epoch 92/100
# 3000/3000 [==============================] - 65s 22ms/step - loss: 3.4342e-04
# Epoch 93/100
# 3000/3000 [==============================] - 65s 22ms/step - loss: 3.4338e-04
# Epoch 94/100
# 3000/3000 [==============================] - 65s 22ms/step - loss: 3.4282e-04
# Epoch 95/100
# 3000/3000 [==============================] - 65s 22ms/step - loss: 3.4304e-04
# Epoch 96/100
# 3000/3000 [==============================] - 65s 22ms/step - loss: 3.4048e-04
# Epoch 97/100
# 3000/3000 [==============================] - 65s 22ms/step - loss: 3.4293e-04
# Epoch 98/100
# 3000/3000 [==============================] - 65s 22ms/step - loss: 3.4074e-04
# Epoch 99/100
# 3000/3000 [==============================] - 65s 22ms/step - loss: 3.3838e-04
# Epoch 100/100
# 3000/3000 [==============================] - 65s 22ms/step - loss: 3.5320e-04

# %%
predicted_list = []
for img in test_list:
    img = np.reshape(img, (1, 512, 512, 1))
    
    
    predicted = np.squeeze(model.predict(img, batch_size=1)) # 각 모델의 prediction을 predictions 리스트에 저장
    predicted_list.append(predicted)

# %%
_, ax = plt.subplots(1,2, figsize=(12,9.338))
ax[0].imshow(np.squeeze(test_list[0]), cmap='gray') # 1열에 원본 이미지
ax[1].imshow(np.squeeze(predicted_list[0].astype('float32')), cmap='gray') # 2열에 LR to SR 이미지
plt.show()

# %%
result_path = r'./hanul/colab result'

import imageio
i = 0
for img in predicted_list:
    img = np.reshape(img, (512, 512, 1))
    imageio.imwrite(result_path+str(i)+'.png', img)
    i+=1
# Out:
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
